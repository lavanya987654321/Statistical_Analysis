# %% [markdown]
# # Exercise-1

# %%
import pandas as pd

# %%
df=pd.read_csv("wearable_tech_sleep_quality_1.csv")

# %% [markdown]
# Top 10 records of the dataset:

# %%
df.head(10)
# Out:
#    Heart_Rate_Variability  Body_Temperature  Movement_During_Sleep  \
# 0               79.934283         37.199678               1.324822
# 1               67.234714         36.962317               1.855481
# 2               82.953771         36.529815               1.207580
# 3              100.460597         36.176532               1.692038
# 4               65.316933         36.849112               0.106385
# 5               65.317261         36.696743               2.213294
# 6              101.584256         36.947597               2.001205
# 7               85.348695         36.817586               1.182911
# 8               60.610512         37.024776               2.659246
# 9               80.851201         36.232382               2.937570
#
#    Sleep_Duration_Hours  Sleep_Quality_Score  Caffeine_Intake_mg  \
# 0              4.638289             1.000000          107.624032
# 1              6.209422             1.000000          104.658589
# 2              6.879592            10.000000            0.000000
# 3             10.331531             1.000000          116.990981
# 4              8.334830             1.000000          223.282908
# 5              5.496778             7.122153           22.576788
# 6              8.229054             1.000000          254.848265
# 7              5.179044             1.000000          198.777482
# 8              9.124037             2.409237           76.576668
# 9              6.793313             1.000000          135.847036
#
#    Stress_Level  Bedtime_Consistency  Light_Exposure_hours
# 0      2.771837             0.657037              7.933949
# 1      3.738138             0.144464              6.992699
# 2      3.115880             0.642949              7.655250
# 3      3.904008             0.453255              9.429463
# 4      4.571699             0.641492             10.555713
# 5      6.674309             0.655386              9.140975
# 6      4.357682             0.821583              8.203446
# 7      1.828749             0.770691             10.996024
# 8      7.280136             0.769314              7.374327
# 9      3.325820             0.788734             10.061839

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# Descriptive statistics are essential for understanding the basic features of a dataset. They provide simple summaries about the sample and the measures, forming the basis of virtually every quantitative analysis of data. Descriptive statistics help to simplify large amounts of data in a sensible way.

# %%
# Calculate basic descriptive statistics
print("Mean:\n")
print(df.mean())
print("\nMedian:\n")
print(df.median())
print("\nMode:\n")
print(df.mode().iloc[0])
print("\nStandard Deviation:\n")
print(df.std())
print("\nVariance:\n")
print(df.var())
# Additional descriptive statistics
print("\nRange:\n")
print(df.max() - df.min())
print("\nSkewness:\n")
print(df.skew())
print("\nKurtosis:\n")
print(df.kurt())
# Out:
# Mean:
#
# Heart_Rate_Variability     70.386641
# Body_Temperature           36.535418
# Movement_During_Sleep       2.005834
# Sleep_Duration_Hours        7.471921
# Sleep_Quality_Score         2.592946
# Caffeine_Intake_mg        148.260148
# Stress_Level                4.940956
# Bedtime_Consistency         0.504222
# Light_Exposure_hours        8.036684
# dtype: float64
#
# Median:
#
# Heart_Rate_Variability     70.506012
# Body_Temperature           36.531539
# Movement_During_Sleep       1.999749
# Sleep_Duration_Hours        7.500277
# Sleep_Quality_Score         1.000000
# Caffeine_Intake_mg        145.717293
# Stress_Level                4.890507
# Bedtime_Consistency         0.500996
# Light_Exposure_hours        8.038248
# dtype: float64
#
# Mode:
#
# Heart_Rate_Variability     5.174653
# Body_Temperature          35.029806
# Movement_During_Sleep     -1.019512
# Sleep_Duration_Hours       3.105827
# Sleep_Quality_Score        1.000000
# Caffeine_Intake_mg         0.000000
# Stress_Level              10.000000
# Bedtime_Consistency        1.000000
# Light_Exposure_hours       0.326689
# Name: 0, dtype: float64
#
# Standard Deviation:
#
# Heart_Rate_Variability    19.584319
# Body_Temperature           0.498727
# Movement_During_Sleep      0.983454
# Sleep_Duration_Hours       1.540699
# Sleep_Quality_Score        2.979500
# Caffeine_Intake_mg        94.031760
# Stress_Level               2.032708
# Bedtime_Consistency        0.204137
# Light_Exposure_hours       2.023371
# dtype: float64
#
# Variance:
#
# Heart_Rate_Variability     383.545541
# Body_Temperature             0.248729
# Movement_During_Sleep        0.967182
# Sleep_Duration_Hours         2.373753
# Sleep_Quality_Score          8.877418
# Caffeine_Intake_mg        8841.971821
# Stress_Level                 4.131904
# Bedtime_Consistency          0.041672
# Light_Exposure_hours         4.094030
# dtype: float64
#
# Range:
#
# Heart_Rate_Variability    141.879977
# Body_Temperature            3.066748
# Movement_During_Sleep       6.945750
# Sleep_Duration_Hours        9.258812
# Sleep_Quality_Score         9.000000
# Caffeine_Intake_mg        400.000000
# Stress_Level               10.000000
# Bedtime_Consistency         1.000000
# Light_Exposure_hours       14.428077
# dtype: float64
#
# Skewness:
#
# Heart_Rate_Variability    0.116976
# Body_Temperature         -0.049396
# Movement_During_Sleep     0.061247
# Sleep_Duration_Hours     -0.002121
# Sleep_Quality_Score       1.669148
# Caffeine_Intake_mg        0.344654
# Stress_Level              0.089971
# Bedtime_Consistency       0.025996
# Light_Exposure_hours     -0.024400
# dtype: float64
#
# Kurtosis:
#
# Heart_Rate_Variability    0.072562
# Body_Temperature          0.058403
# Movement_During_Sleep     0.172201
# Sleep_Duration_Hours     -0.229274
# Sleep_Quality_Score       1.192807
# Caffeine_Intake_mg       -0.344550
# Stress_Level             -0.319646
# Bedtime_Consistency      -0.276870
# Light_Exposure_hours      0.163532
# dtype: float64

# %% [markdown]
# ## Inferential Statistics:
# Inferential statistics allow us to make predictions or inferences about a population based on a sample of data. Unlike descriptive statistics, which simply summarize data, inferential statistics help us draw conclusions and make predictions beyond the immediate data.

# %%
from scipy import stats

# Example data: BMI values
stress_values = df['Stress_Level']

# Hypothetical population mean for BMI
population_mean = 1.50

# Perform one-sample t-test
t_stat, p_value = stats.ttest_1samp(bmi_values, population_mean)

print(f"T-Statistic: {t_stat}")
print(f"P-Value: {p_value}")
# Out:
# T-Statistic: 53.53083646146371
# P-Value: 9.85968655333537e-296

# %% [markdown]
# ## Confidence Intervals:
# A confidence interval is a range of values, derived from the sample data, that is likely to contain the true population parameter. Confidence intervals provide an estimate of the uncertainty associated with a sample statistic, allowing researchers to gauge the precision of their estimates.

# %%
import numpy as np
from scipy import stats

# Sample mean and standard error for BMI
sample_mean = np.mean(stress_values)
standard_error = stats.sem(stress_values)

# Compute 95% confidence interval for BMI
confidence_interval = stats.norm.interval(0.95, loc=sample_mean, scale=standard_error)

print(f"95% Confidence Interval for BMI: {confidence_interval}")
# Out:
# 95% Confidence Interval for BMI: (4.814969806809296, 5.06694233002349)

# %% [markdown]
# ## Regression Analysis:
# Regression analysis is used to model the relationship between dependent and independent variables. It helps in understanding how the typical value of the dependent variable changes when any one of the independent variables is varied. Regression analysis is fundamental in predicting outcomes and identifying trends in data.

# %%
import statsmodels.api as sm

# Define independent variable (add constant for intercept)
X = df[['Stress_Level']]
X = sm.add_constant(X)

# Define dependent variable
y = df['Heart_Rate_Variability']

# Fit linear regression model
model = sm.OLS(y, X).fit()

# Print model summary
print(model.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Heart_Rate_Variability   R-squared:                       0.001
# Model:                                OLS   Adj. R-squared:                  0.000
# Method:                     Least Squares   F-statistic:                     1.251
# Date:                    Fri, 06 Sep 2024   Prob (F-statistic):              0.264
# Time:                            14:48:46   Log-Likelihood:                -4392.5
# No. Observations:                    1000   AIC:                             8789.
# Df Residuals:                         998   BIC:                             8799.
# Df Model:                               1
# Covariance Type:                nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           72.0712      1.628     44.262      0.000      68.876      75.266
# Stress_Level    -0.3409      0.305     -1.119      0.264      -0.939       0.257
# ==============================================================================
# Omnibus:                        2.369   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.306   Jarque-Bera (JB):                2.265
# Skew:                           0.114   Prob(JB):                        0.322
# Kurtosis:                       3.052   Cond. No.                         14.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plot data and regression line
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Stress_Level', y='Heart_Rate_Variability', data=df, alpha=0.7)
sns.regplot(x='Stress_Level', y='Heart_Rate_Variability', data=df, scatter=False, color='red')

# Add labels and title
plt.xlabel('Stress_Level')
plt.ylabel('Heart_Rate_Variability')
plt.title('Stress_Level vs Heart_Rate_Variability with Regression Line')

# Show plot
plt.grid(True)
plt.show()
